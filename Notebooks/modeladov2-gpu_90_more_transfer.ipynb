# %% [markdown]
# Esta fase de la metdologia consiste en extraer el valor de los datos desarrollando un modelo que aprenda de los patrones en estos.
#
# * El diagrama en cuestion de esta fase esta a continuacion:

# %% [markdown]
# ![Imagen_mapa](imagen_modelado_general.png)

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator #generator de imagenes
from sklearn.utils import class_weight
from sklearn.metrics import classification_report

# %%
tf.keras.backend.clear_session()

# %%
tf.random.set_seed(42)#semilla 42, para la reproducibilidad de resultados

# %% [markdown]
# ### Canalizacion de datos
#
# * Preparamos la canalizacion de datos, a partir de las imagenes del disco.

# %%
train_datagen=ImageDataGenerator(
            rescale=1.0/255, #escalamos los datos en rangos de [-1,1] El modelo MobileNetv2 espera esta configuracion
            rotation_range = 45,
            zoom_range = 0.2,
            shear_range = 0.2,
            width_shift_range = 0.2,
            height_shift_range = 0.2,
            horizontal_flip=True,
            vertical_flip = True,
            fill_mode = 'nearest'
        )
#sobre los datos de validacion y test no se hace ningun aumento de datos.
validation_datagen=ImageDataGenerator(rescale=1.0/255) #escalamiento de validacion a un rango de [0,1]
test_datagen=ImageDataGenerator(rescale=1.0/255)       #escalamiento de test a un rango de [0,1]

# %%
#definimos las rutas para el acceso a los datos
train_path="../input/datasetscovidsplit/Datasets/train"
validation_path="../input/datasetscovidsplit/Datasets/val"
test_path="../input/datasetscovidsplit/Datasets/test"

#creamos los generadores de datos a partir de los flujos de informacion
BATCH_SIZE=32 #tamaño del lote que se ira pasando poco a poco
IMAGE_SIZE=(256,256)

train_generator=train_datagen.flow_from_directory(
    train_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

validation_generator=train_datagen.flow_from_directory(
    validation_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_generator=train_datagen.flow_from_directory(
    test_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 15238 images belonging to 4 classes.
# Found 1694 images belonging to 4 classes.
# Found 4233 images belonging to 4 classes.

# %% [markdown]
# ### Tecnica para el tratamiento de datos Desbalaceados. Focal Loss Categorical
#
# * Para ello personalizaremos una funcion de costo
# * En nuestro caso trabajamos con imagenes, y tenemos la opcion de tratar este desbalanceo **penalizando los pesos de las clases** mayoritarias a favor de las clases minoritarias.

# %%
def focal_loss(gamma=2., alpha=4.):

    gamma = float(gamma)
    alpha = float(alpha)

    def focal_loss_fixed(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        Notice: y_pred is probability after softmax
        gradient is d(Fl)/d(p_t) not d(Fl)/d(x) as described in paper
        d(Fl)/d(p_t) * [p_t(1-p_t)] = d(Fl)/d(x)
        Focal Loss for Dense Object Detection
        https://arxiv.org/abs/1708.02002
        Arguments:
            y_true {tensor} -- ground truth labels, shape of [batch_size, num_cls]
            y_pred {tensor} -- model's output, shape of [batch_size, num_cls]
        Keyword Arguments:
            gamma {float} -- (default: {2.0})
            alpha {float} -- (default: {4.0})
        Returns:
            [tensor] -- loss.
        """
        epsilon = 1.e-9
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        return tf.reduce_mean(reduced_fl)
    return focal_loss_fixed

# %% [markdown]
# ### Selección de tecnicas de Modelado
#
# Al tratarse de un problema de clasificacion de imagenes entre los posibles candidatos tenemos:
#
# * MultiLayer Pereptron: Red neuronal de capas densamente conectadas
# * Convolutional Neuronal Network: Red neuronal convolucional.
# * Modelos de machine learning clasico (Maquinas de soporte vectorial, arboles de decision e impulso, etc.)
#
# Escogi la red neuronal convolucional porque **aprende de patrones locales** como rasgos pequeños y en bloques de informacion, mientras que el **MLP** aprende de patrones especficos, e decir de todo el espacio de entrada en general.

# %% [markdown]
# ### Construcción de la arquitectura del modelo
#
# * Para la construccion de la arquitectura crearemos un modelo desde 0 con una arquitectura de red neuronal solida.

# %%
INPUT_SHAPE=(256,256,3) #imagen de 256x256 con 4 canales de datos RGB
N_CLASSES=4
BASE_LEARNING_RATE=0.001

def ConvolutionalBlock(filters,name):
    partial_block=tf.keras.models.Sequential(name=name)
    partial_block.add(tf.keras.layers.Conv2D(filters,3,activation="relu",padding="same"))
    partial_block.add(tf.keras.layers.Conv2D(filters,3,activation="relu",padding="same"))
    partial_block.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
    
    return partial_block

def DenseBlock(units,name):
    dense_block=tf.keras.models.Sequential(name=name)
    dense_block.add(tf.keras.layers.Dense(units,activation="relu"))
    dense_block.add(tf.keras.layers.Dropout(0.2))
    
    return dense_block

def build_base_model():
    #arquitectura del modelo
    inputs=tf.keras.Input(shape=INPUT_SHAPE,name="input")
    x=ConvolutionalBlock(64,"conv_block_64")(inputs)
    x=ConvolutionalBlock(128,"conv_block_128")(x)
    x=ConvolutionalBlock(256,"conv_block_256")(x)
    
    x=tf.keras.layers.BatchNormalization(name="batch_normalization")(x)
    x=tf.keras.layers.GlobalAveragePooling2D(name="average_intermedio")(x)
    

    x=tf.keras.layers.Dense(256,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.5)(x)
    x=tf.keras.layers.Dense(128,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.5)(x)
    
    outputs=tf.keras.layers.Dense(N_CLASSES,activation="softmax",name="output")(x)
    
    model=tf.keras.Model(inputs,outputs,name="model_covid_detector")
    #compilacion del modelo
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=BASE_LEARNING_RATE),
        loss=focal_loss(alpha=1.0),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.Recall(name="recall")    
        ]
    )
    
    return model

# %%
test_model=build_base_model()

# %%
test_model.summary()
# Out:
# Model: "model_covid_detector"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv_block_64 (Sequential)   (None, 128, 128, 64)      38720
# _________________________________________________________________
# conv_block_128 (Sequential)  (None, 64, 64, 128)       221440
# _________________________________________________________________
# conv_block_256 (Sequential)  (None, 32, 32, 256)       885248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 256)       1024
# _________________________________________________________________
# average_intermedio (GlobalAv (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 4)                 516
# =================================================================
# Total params: 1,245,636
# Trainable params: 1,245,124
# Non-trainable params: 512
# _________________________________________________________________

# %%
plot_model(test_model,"model_build.png",show_shapes=True)

# %% [markdown]
# Una vez obtenidos la arquitectura del modelo
# * Generando **Callbacks** para detener el entrenamiento cuando no se tienen buenos resultados

# %%
#cuando la funcion de perdida ya no mejora en los datos de validacion.
early_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=10,
                                                mode="min",
                                                restore_best_weights=True) 
model_checkpoint=tf.keras.callbacks.ModelCheckpoint("base_model_best_check.h5",save_best_only=True)
n_epochs=100

# %% [markdown]
# ### Entrenamiento el modelo BASE

# %%
base_model=build_base_model()
model_history=base_model.fit(
                    train_generator,
                    epochs=n_epochs,
                    validation_data=validation_generator,
                    validation_steps=validation_generator.samples//validation_generator.batch_size,
                    callbacks=[early_stopping,model_checkpoint],
                    #class_weight=class_weights,#penalizacion de pesos para el balanceo,
                    workers=8
            )
# Out:
# Epoch 1/100
# 477/477 [==============================] - 263s 523ms/step - loss: 0.6348 - accuracy: 0.4691 - recall: 0.0462 - val_loss: 0.6790 - val_accuracy: 0.4369 - val_recall: 0.0078
# Epoch 2/100
# 477/477 [==============================] - 250s 519ms/step - loss: 0.5358 - accuracy: 0.5462 - recall: 0.1591 - val_loss: 0.4668 - val_accuracy: 0.5847 - val_recall: 0.1226
# Epoch 3/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.4691 - accuracy: 0.5941 - recall: 0.2679 - val_loss: 0.8173 - val_accuracy: 0.3287 - val_recall: 0.2734
# Epoch 4/100
# 477/477 [==============================] - 249s 514ms/step - loss: 0.4127 - accuracy: 0.6420 - recall: 0.3646 - val_loss: 0.3782 - val_accuracy: 0.6575 - val_recall: 0.3996
# Epoch 5/100
# 477/477 [==============================] - 249s 517ms/step - loss: 0.3695 - accuracy: 0.6576 - recall: 0.4050 - val_loss: 0.3884 - val_accuracy: 0.6106 - val_recall: 0.3516
# Epoch 6/100
# 477/477 [==============================] - 246s 510ms/step - loss: 0.3405 - accuracy: 0.6798 - recall: 0.4445 - val_loss: 0.7877 - val_accuracy: 0.6472 - val_recall: 0.4754
# Epoch 7/100
# 477/477 [==============================] - 247s 512ms/step - loss: 0.3265 - accuracy: 0.6946 - recall: 0.4759 - val_loss: 0.4275 - val_accuracy: 0.6869 - val_recall: 0.5739
# Epoch 8/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.2984 - accuracy: 0.7159 - recall: 0.5257 - val_loss: 0.3780 - val_accuracy: 0.6544 - val_recall: 0.4369
# Epoch 9/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.2768 - accuracy: 0.7355 - recall: 0.5729 - val_loss: 0.2983 - val_accuracy: 0.6713 - val_recall: 0.5222
# Epoch 10/100
# 477/477 [==============================] - 245s 509ms/step - loss: 0.2550 - accuracy: 0.7553 - recall: 0.6112 - val_loss: 0.3380 - val_accuracy: 0.6737 - val_recall: 0.4904
# Epoch 11/100
# 477/477 [==============================] - 247s 512ms/step - loss: 0.2401 - accuracy: 0.7706 - recall: 0.6469 - val_loss: 0.3294 - val_accuracy: 0.6815 - val_recall: 0.5745
# Epoch 12/100
# 477/477 [==============================] - 244s 506ms/step - loss: 0.2141 - accuracy: 0.7836 - recall: 0.6842 - val_loss: 0.3042 - val_accuracy: 0.6881 - val_recall: 0.6316
# Epoch 13/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.2078 - accuracy: 0.7966 - recall: 0.7000 - val_loss: 0.2581 - val_accuracy: 0.7476 - val_recall: 0.6196
# Epoch 14/100
# 477/477 [==============================] - 247s 512ms/step - loss: 0.1969 - accuracy: 0.7976 - recall: 0.7080 - val_loss: 0.2379 - val_accuracy: 0.7590 - val_recall: 0.6695
# Epoch 15/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.1830 - accuracy: 0.8165 - recall: 0.7382 - val_loss: 0.2945 - val_accuracy: 0.7416 - val_recall: 0.6388
# Epoch 16/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.1760 - accuracy: 0.8219 - recall: 0.7540 - val_loss: 0.1563 - val_accuracy: 0.8239 - val_recall: 0.7614
# Epoch 17/100
# 477/477 [==============================] - 247s 511ms/step - loss: 0.1777 - accuracy: 0.8189 - recall: 0.7559 - val_loss: 0.1969 - val_accuracy: 0.7770 - val_recall: 0.7127
# Epoch 18/100
# 477/477 [==============================] - 247s 511ms/step - loss: 0.1651 - accuracy: 0.8286 - recall: 0.7715 - val_loss: 0.1838 - val_accuracy: 0.8281 - val_recall: 0.7837
# Epoch 19/100
# 477/477 [==============================] - 247s 512ms/step - loss: 0.1599 - accuracy: 0.8322 - recall: 0.7847 - val_loss: 0.2577 - val_accuracy: 0.7632 - val_recall: 0.6683
# Epoch 20/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.1626 - accuracy: 0.8367 - recall: 0.7818 - val_loss: 0.1522 - val_accuracy: 0.8407 - val_recall: 0.7849
# Epoch 21/100
# 477/477 [==============================] - 247s 511ms/step - loss: 0.1599 - accuracy: 0.8325 - recall: 0.7817 - val_loss: 0.3393 - val_accuracy: 0.7518 - val_recall: 0.7272
# Epoch 22/100
# 477/477 [==============================] - 247s 510ms/step - loss: 0.1526 - accuracy: 0.8451 - recall: 0.7987 - val_loss: 0.2057 - val_accuracy: 0.8101 - val_recall: 0.7812
# Epoch 23/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1480 - accuracy: 0.8433 - recall: 0.7967 - val_loss: 0.1683 - val_accuracy: 0.8371 - val_recall: 0.7728
# Epoch 24/100
# 477/477 [==============================] - 246s 511ms/step - loss: 0.1333 - accuracy: 0.8573 - recall: 0.8177 - val_loss: 0.2700 - val_accuracy: 0.7590 - val_recall: 0.6803
# Epoch 25/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.1354 - accuracy: 0.8548 - recall: 0.8144 - val_loss: 0.1969 - val_accuracy: 0.7975 - val_recall: 0.7212
# Epoch 26/100
# 477/477 [==============================] - 246s 510ms/step - loss: 0.1395 - accuracy: 0.8553 - recall: 0.8129 - val_loss: 0.1623 - val_accuracy: 0.8353 - val_recall: 0.7891
# Epoch 27/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.1294 - accuracy: 0.8570 - recall: 0.8245 - val_loss: 0.1833 - val_accuracy: 0.8035 - val_recall: 0.7236
# Epoch 28/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1219 - accuracy: 0.8655 - recall: 0.8341 - val_loss: 0.2440 - val_accuracy: 0.7368 - val_recall: 0.7163
# Epoch 29/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.1191 - accuracy: 0.8698 - recall: 0.8380 - val_loss: 0.2534 - val_accuracy: 0.7392 - val_recall: 0.6743
# Epoch 30/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.1245 - accuracy: 0.8659 - recall: 0.8304 - val_loss: 0.1345 - val_accuracy: 0.8468 - val_recall: 0.8119
# Epoch 31/100
# 477/477 [==============================] - 246s 510ms/step - loss: 0.1283 - accuracy: 0.8613 - recall: 0.8265 - val_loss: 0.1463 - val_accuracy: 0.8576 - val_recall: 0.8065
# Epoch 32/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.1233 - accuracy: 0.8653 - recall: 0.8362 - val_loss: 0.1632 - val_accuracy: 0.8359 - val_recall: 0.7710
# Epoch 33/100
# 477/477 [==============================] - 246s 510ms/step - loss: 0.1179 - accuracy: 0.8662 - recall: 0.8371 - val_loss: 0.3682 - val_accuracy: 0.7121 - val_recall: 0.6797
# Epoch 34/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1193 - accuracy: 0.8691 - recall: 0.8341 - val_loss: 0.2050 - val_accuracy: 0.7927 - val_recall: 0.7236
# Epoch 35/100
# 477/477 [==============================] - 248s 514ms/step - loss: 0.1191 - accuracy: 0.8715 - recall: 0.8433 - val_loss: 0.2259 - val_accuracy: 0.7909 - val_recall: 0.7668
# Epoch 36/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.1133 - accuracy: 0.8775 - recall: 0.8491 - val_loss: 0.1216 - val_accuracy: 0.8546 - val_recall: 0.8257
# Epoch 37/100
# 477/477 [==============================] - 249s 514ms/step - loss: 0.1207 - accuracy: 0.8688 - recall: 0.8413 - val_loss: 0.1811 - val_accuracy: 0.8377 - val_recall: 0.8113
# Epoch 38/100
# 477/477 [==============================] - 248s 519ms/step - loss: 0.1172 - accuracy: 0.8707 - recall: 0.8442 - val_loss: 0.0964 - val_accuracy: 0.8756 - val_recall: 0.8648
# Epoch 39/100
# 477/477 [==============================] - 247s 512ms/step - loss: 0.1128 - accuracy: 0.8787 - recall: 0.8542 - val_loss: 0.5786 - val_accuracy: 0.6767 - val_recall: 0.6316
# Epoch 40/100
# 477/477 [==============================] - 248s 514ms/step - loss: 0.1183 - accuracy: 0.8728 - recall: 0.8439 - val_loss: 0.1529 - val_accuracy: 0.8293 - val_recall: 0.8101
# Epoch 41/100
# 477/477 [==============================] - 246s 510ms/step - loss: 0.1095 - accuracy: 0.8796 - recall: 0.8583 - val_loss: 0.1270 - val_accuracy: 0.8389 - val_recall: 0.8137
# Epoch 42/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.1074 - accuracy: 0.8846 - recall: 0.8593 - val_loss: 0.1147 - val_accuracy: 0.8696 - val_recall: 0.8546
# Epoch 43/100
# 477/477 [==============================] - 245s 506ms/step - loss: 0.1110 - accuracy: 0.8867 - recall: 0.8610 - val_loss: 0.1068 - val_accuracy: 0.8720 - val_recall: 0.8480
# Epoch 44/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1006 - accuracy: 0.8905 - recall: 0.8693 - val_loss: 0.7133 - val_accuracy: 0.5174 - val_recall: 0.4507
# Epoch 45/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.1040 - accuracy: 0.8761 - recall: 0.8574 - val_loss: 0.2328 - val_accuracy: 0.7458 - val_recall: 0.7206
# Epoch 46/100
# 477/477 [==============================] - 245s 508ms/step - loss: 0.0965 - accuracy: 0.8884 - recall: 0.8694 - val_loss: 0.1104 - val_accuracy: 0.8738 - val_recall: 0.8588
# Epoch 47/100
# 477/477 [==============================] - 246s 508ms/step - loss: 0.1004 - accuracy: 0.8839 - recall: 0.8660 - val_loss: 0.2065 - val_accuracy: 0.8029 - val_recall: 0.7716
# Epoch 48/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1011 - accuracy: 0.8836 - recall: 0.8633 - val_loss: 0.1480 - val_accuracy: 0.8726 - val_recall: 0.8564

# %%
#guardamos el modelo generado
base_model.save("./model_base.h5")

# %%
#deseo guardar el History devuelto del entrenamiento
dfhist=pd.DataFrame(model_history.history)
dfhist.to_csv("./model_history.csv",index=False)

# %% [markdown]
# Trazamos la curva de la accuracy y funcion de perdida

# %% [markdown]
# * Creamos una funcion para reutilizar la funcion que genera el grafico, para los modelos que se probaran mas adelante.

# %%
def plot_metrics(history,metrics=[]): #retorna una lista de tuplas
    fig,axes=plt.subplots(1,len(metrics))
    fig.set_size_inches(15,5)
    graph=pd.DataFrame(history)
    for i,ax in enumerate(axes.flat):
        graph[list(metrics[i])].plot(kind="line",style="-",ax=ax)
        ax.set_title(" VS ".join(list(metrics[i])))
        ax.grid(True)
    plt.show()

# %%
df_history=pd.read_csv("model_history.csv")
history=df_history.to_dict("list")
metrics=[("accuracy","val_accuracy"),("loss","val_loss")]
plot_metrics(history,metrics=metrics)

# %%
df_history[["recall","val_recall"]].plot(kind="line",style="-")
plt.grid(True)

# %%
#obtenemos el numero de epocas donde se detuvo y lo configuramos como un epoch inicial para el siguiente
#entrenamiento
EPOCH_STOP=model_history.epoch[-1]
print("El modelo se entreno en",EPOCH_STOP,"Epochs")
# Out:
# El modelo se entreno en 47 Epochs

# %% [markdown]
# * El entrenamiento del modelo se detuvo en 47 epochs lo que nos dice que la funcion de perdida en la data de validacion no mejoro por 10 epochs consecutivos, probablemente, ya no mejore para futuras epocas.
#
# Ahora veamos el rendimiento del modelo base en los datos de entrenamiento y validacion

# %%
base_model.evaluate(train_generator)
# Out:
# 477/477 [==============================] - 239s 501ms/step - loss: 0.0899 - accuracy: 0.8939 - recall: 0.8789
# [0.08986824005842209, 0.8939493298530579, 0.8788554668426514]

# %%
base_model.evaluate(validation_generator)
# Out:
# 53/53 [==============================] - 29s 541ms/step - loss: 0.1009 - accuracy: 0.8760 - recall: 0.8601
# [0.10091470181941986, 0.8760330677032471, 0.860094428062439]

# %% [markdown]
# * Mostramos la matriz de confusion en los datos de entrenamiento y validacion
#
# Para el conjunto de entrenamiento

# %%
y_true=train_generator.classes
predictions=base_model.predict(train_generator)
y_pred=np.argmax(predictions,axis=1)

# %%
train_generator.class_indices
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
#obtenemos la matriz de confusion de sklearn
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set()
classes=train_generator.class_indices.keys()
mat_train=confusion_matrix(y_true,y_pred)
sns.heatmap(mat_train,square=True,annot=True,fmt="0.2f",cmap="coolwarm",xticklabels=classes,yticklabels=classes)
plt.xticks(rotation=60)
plt.title("Matriz de confusion entrenamiento")
plt.show()

# %% [markdown]
# * Reporte de clasificacion para el conjunto de entrenamiento

# %%
report=classification_report(y_true,y_pred,target_names=list(train_generator.class_indices.keys()))
print(report)
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.16      0.17      0.17      2604
#    Lung_Opacity       0.28      0.24      0.26      4328
#          Normal       0.48      0.52      0.50      7338
# Viral Pneumonia       0.06      0.06      0.06       968
#
#        accuracy                           0.35     15238
#       macro avg       0.25      0.25      0.25     15238
#    weighted avg       0.34      0.35      0.35     15238

# %% [markdown]
# * Para el conjunto de validacion

# %%
y_true=validation_generator.classes
predictions=base_model.predict(validation_generator)
y_pred=np.argmax(predictions,axis=1)

# %%
classes=validation_generator.class_indices.keys()
mat_val=confusion_matrix(y_true,y_pred)
sns.heatmap(mat_val,square=True,annot=True,fmt="0.2f",cmap="coolwarm",xticklabels=classes,yticklabels=classes)
plt.xticks(rotation=60)
plt.title("Matriz de confusion validacion")
plt.show()

# %% [markdown]
# * Reporte de clasificacion para los datos de validacion

# %%
report=classification_report(y_true,y_pred,target_names=list(train_generator.class_indices.keys()))
print(report)
# Out:
#                  precision    recall  f1-score   support
#
#           COVID       0.18      0.18      0.18       289
#    Lung_Opacity       0.29      0.25      0.26       481
#          Normal       0.47      0.51      0.49       816
# Viral Pneumonia       0.06      0.06      0.06       108
#
#        accuracy                           0.35      1694
#       macro avg       0.25      0.25      0.25      1694
#    weighted avg       0.34      0.35      0.35      1694

# %%
#guardamos la documentacion del entrenamiento
train_generator.class_indices.keys()
# Out:
# dict_keys(['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia'])

# %% [markdown]
# ### RESULTADOS FINALES: MODELO CON PERDIDA FOCAL PARA EL BALANCEO DE CLASES
# * El modelo base ha obtenido un puntaje de accuracy **ACC=89%** y recall **RECALL=87.89%** en el **conjunto de entrenamiento**.
#
# * El modelo ha obtendio un puntaje de accuracy **ACC=87.%** y recall **RECALL=86.%** en el **conjunto de validacion**.
#
# **IMPORTANTE**: El modelo ha alcanzado un poco equilibrio entre los datos de entrenamiento y validacion, lo que siginifica que es un modelo final con aproximadamente 82% de precision. Este modelo pasará a la **Fase de evaluación del modelo**.

# %% [markdown]
# # Aplicación de Transfer Learning usando DenseNet169 y tecnica de anti-desbalanceo Focal Loss Categorical
#
# * Se escogio la arquitectura DenseNet169 por tener un mayor precision sobre el conjunto de datos Image.net en la que fue entrenado.

# %%
INPUT_SHAPE=(256,256,3)
BASE_LEARNING_RATE=0.001
def build_model_transferLearning():
    dense_net169=tf.keras.applications.DenseNet169(
                weights="imagenet",
                input_shape=INPUT_SHAPE,
                include_top=False
            )
    #descongelamos algunas capas
    dense_net169.trainable=True
    for layer in dense_net169.layers:
        if 'conv5' in layer.name:
            layer.trainable=True
        else:
            layer.trainable=False
    #creamos el modelo
    inputs=tf.keras.Input(shape=INPUT_SHAPE)
    x=dense_net169(inputs)
    x=tf.keras.layers.Flatten()(x)
    
    x=tf.keras.layers.BatchNormalization()(x)
    x=tf.keras.layers.Dense(256,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.4)(x)
    
    x=tf.keras.layers.BatchNormalization()(x)
    x=tf.keras.layers.Dense(128,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.4)(x)
    
    outputs=tf.keras.layers.Dense(4,activation="softmax")(x)
    
    model=tf.keras.Model(inputs,outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=BASE_LEARNING_RATE),
        loss=focal_loss(alpha=1.0),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.Recall(name="recall")    
        ]
    )
    return model

# %%
transfer_model=build_model_transferLearning()

# %%
transfer_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# densenet169 (Functional)     (None, 8, 8, 1664)        12642880
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 106496)            0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 106496)            425984
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               27263232
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 40,366,532
# Trainable params: 33,423,748
# Non-trainable params: 6,942,784
# _________________________________________________________________

# %%
plot_model(transfer_model,"transfer_densenet.png",show_shapes=True)

# %%
transfer_model=build_model_transferLearning()
history_model=transfer_model.fit(
                    train_generator,
                    epochs=n_epochs,
                    validation_data=validation_generator,
                    validation_steps=validation_generator.samples//validation_generator.batch_size,
                    callbacks=[early_stopping,model_checkpoint],
                    #class_weight=class_weights,#penalizacion de pesos para el balanceo,
                    workers=8
            )
# Out:
# Epoch 1/100
# 477/477 [==============================] - 271s 535ms/step - loss: 0.5193 - accuracy: 0.6799 - recall: 0.6062 - val_loss: 0.2408 - val_accuracy: 0.8035 - val_recall: 0.7362
# Epoch 2/100
# 477/477 [==============================] - 257s 533ms/step - loss: 0.2013 - accuracy: 0.8167 - recall: 0.7589 - val_loss: 0.1378 - val_accuracy: 0.8684 - val_recall: 0.8011
# Epoch 3/100
# 477/477 [==============================] - 255s 528ms/step - loss: 0.1557 - accuracy: 0.8450 - recall: 0.7990 - val_loss: 0.1225 - val_accuracy: 0.8684 - val_recall: 0.8419
# Epoch 4/100
# 477/477 [==============================] - 256s 530ms/step - loss: 0.1407 - accuracy: 0.8541 - recall: 0.8155 - val_loss: 0.1193 - val_accuracy: 0.8648 - val_recall: 0.8305
# Epoch 5/100
# 477/477 [==============================] - 255s 528ms/step - loss: 0.1400 - accuracy: 0.8621 - recall: 0.8270 - val_loss: 0.0893 - val_accuracy: 0.9026 - val_recall: 0.8786
# Epoch 6/100
# 477/477 [==============================] - 253s 523ms/step - loss: 0.1202 - accuracy: 0.8740 - recall: 0.8419 - val_loss: 0.1205 - val_accuracy: 0.8708 - val_recall: 0.8401
# Epoch 7/100
# 477/477 [==============================] - 252s 522ms/step - loss: 0.1200 - accuracy: 0.8763 - recall: 0.8464 - val_loss: 0.1295 - val_accuracy: 0.8365 - val_recall: 0.8191
# Epoch 8/100
# 477/477 [==============================] - 254s 525ms/step - loss: 0.1074 - accuracy: 0.8856 - recall: 0.8636 - val_loss: 0.0833 - val_accuracy: 0.9050 - val_recall: 0.8834
# Epoch 9/100
# 477/477 [==============================] - 253s 524ms/step - loss: 0.1051 - accuracy: 0.8911 - recall: 0.8665 - val_loss: 0.0933 - val_accuracy: 0.9020 - val_recall: 0.8858
# Epoch 10/100
# 477/477 [==============================] - 252s 522ms/step - loss: 0.1020 - accuracy: 0.8902 - recall: 0.8637 - val_loss: 0.1118 - val_accuracy: 0.8750 - val_recall: 0.8504
# Epoch 11/100
# 477/477 [==============================] - 253s 523ms/step - loss: 0.1013 - accuracy: 0.8907 - recall: 0.8672 - val_loss: 0.0961 - val_accuracy: 0.8834 - val_recall: 0.8714
# Epoch 12/100
# 477/477 [==============================] - 253s 524ms/step - loss: 0.0992 - accuracy: 0.8947 - recall: 0.8778 - val_loss: 0.0912 - val_accuracy: 0.9014 - val_recall: 0.8858
# Epoch 13/100
# 477/477 [==============================] - 251s 519ms/step - loss: 0.0996 - accuracy: 0.8963 - recall: 0.8682 - val_loss: 0.0888 - val_accuracy: 0.9020 - val_recall: 0.8900
# Epoch 14/100
# 477/477 [==============================] - 251s 521ms/step - loss: 0.0983 - accuracy: 0.8935 - recall: 0.8730 - val_loss: 0.1146 - val_accuracy: 0.9050 - val_recall: 0.8942
# Epoch 15/100
# 477/477 [==============================] - 251s 520ms/step - loss: 0.0989 - accuracy: 0.8995 - recall: 0.8787 - val_loss: 0.0836 - val_accuracy: 0.9219 - val_recall: 0.9026
# Epoch 16/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0952 - accuracy: 0.8957 - recall: 0.8745 - val_loss: 0.0787 - val_accuracy: 0.9165 - val_recall: 0.9087
# Epoch 17/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0889 - accuracy: 0.9073 - recall: 0.8883 - val_loss: 0.0825 - val_accuracy: 0.9201 - val_recall: 0.9087
# Epoch 18/100
# 477/477 [==============================] - 249s 517ms/step - loss: 0.0854 - accuracy: 0.9028 - recall: 0.8875 - val_loss: 0.1011 - val_accuracy: 0.8966 - val_recall: 0.8678
# Epoch 19/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0918 - accuracy: 0.9014 - recall: 0.8814 - val_loss: 0.0775 - val_accuracy: 0.9117 - val_recall: 0.9032
# Epoch 20/100
# 477/477 [==============================] - 250s 519ms/step - loss: 0.0867 - accuracy: 0.9079 - recall: 0.8950 - val_loss: 0.0683 - val_accuracy: 0.9213 - val_recall: 0.9081
# Epoch 21/100
# 477/477 [==============================] - 251s 520ms/step - loss: 0.0839 - accuracy: 0.9107 - recall: 0.8950 - val_loss: 0.0726 - val_accuracy: 0.9117 - val_recall: 0.8930
# Epoch 22/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0792 - accuracy: 0.9117 - recall: 0.8959 - val_loss: 0.0835 - val_accuracy: 0.9014 - val_recall: 0.8852
# Epoch 23/100
# 477/477 [==============================] - 250s 516ms/step - loss: 0.0790 - accuracy: 0.9133 - recall: 0.8994 - val_loss: 0.0841 - val_accuracy: 0.9087 - val_recall: 0.8984
# Epoch 24/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0784 - accuracy: 0.9145 - recall: 0.9010 - val_loss: 0.0812 - val_accuracy: 0.8984 - val_recall: 0.8804
# Epoch 25/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0832 - accuracy: 0.9065 - recall: 0.8932 - val_loss: 0.0745 - val_accuracy: 0.9207 - val_recall: 0.9111
# Epoch 26/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0834 - accuracy: 0.9106 - recall: 0.8982 - val_loss: 0.0699 - val_accuracy: 0.9081 - val_recall: 0.8972
# Epoch 27/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0729 - accuracy: 0.9204 - recall: 0.9092 - val_loss: 0.0845 - val_accuracy: 0.9062 - val_recall: 0.8900
# Epoch 28/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0738 - accuracy: 0.9199 - recall: 0.9073 - val_loss: 0.0705 - val_accuracy: 0.9219 - val_recall: 0.9147
# Epoch 29/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0759 - accuracy: 0.9116 - recall: 0.9023 - val_loss: 0.0677 - val_accuracy: 0.9255 - val_recall: 0.9099
# Epoch 30/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0714 - accuracy: 0.9199 - recall: 0.9087 - val_loss: 0.0762 - val_accuracy: 0.9123 - val_recall: 0.9050
# Epoch 31/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0811 - accuracy: 0.9131 - recall: 0.9012 - val_loss: 0.0779 - val_accuracy: 0.9135 - val_recall: 0.8990
# Epoch 32/100
# 477/477 [==============================] - 250s 518ms/step - loss: 0.0681 - accuracy: 0.9218 - recall: 0.9117 - val_loss: 0.0710 - val_accuracy: 0.9183 - val_recall: 0.9123
# Epoch 33/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0718 - accuracy: 0.9237 - recall: 0.9133 - val_loss: 0.0660 - val_accuracy: 0.9267 - val_recall: 0.9147
# Epoch 34/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.0730 - accuracy: 0.9183 - recall: 0.9074 - val_loss: 0.0705 - val_accuracy: 0.9231 - val_recall: 0.9050
# Epoch 35/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.0687 - accuracy: 0.9201 - recall: 0.9095 - val_loss: 0.0701 - val_accuracy: 0.9243 - val_recall: 0.9171
# Epoch 36/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0695 - accuracy: 0.9194 - recall: 0.9082 - val_loss: 0.0629 - val_accuracy: 0.9249 - val_recall: 0.9171
# Epoch 37/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0652 - accuracy: 0.9269 - recall: 0.9180 - val_loss: 0.0568 - val_accuracy: 0.9321 - val_recall: 0.9261
# Epoch 38/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0667 - accuracy: 0.9264 - recall: 0.9186 - val_loss: 0.0590 - val_accuracy: 0.9291 - val_recall: 0.9201
# Epoch 39/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0642 - accuracy: 0.9227 - recall: 0.9149 - val_loss: 0.0725 - val_accuracy: 0.9243 - val_recall: 0.9213
# Epoch 40/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0641 - accuracy: 0.9241 - recall: 0.9169 - val_loss: 0.0595 - val_accuracy: 0.9291 - val_recall: 0.9219
# Epoch 41/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.0694 - accuracy: 0.9224 - recall: 0.9110 - val_loss: 0.0586 - val_accuracy: 0.9351 - val_recall: 0.9291
# Epoch 42/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0601 - accuracy: 0.9329 - recall: 0.9243 - val_loss: 0.0639 - val_accuracy: 0.9279 - val_recall: 0.9153
# Epoch 43/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0643 - accuracy: 0.9241 - recall: 0.9147 - val_loss: 0.0647 - val_accuracy: 0.9321 - val_recall: 0.9273
# Epoch 44/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0644 - accuracy: 0.9262 - recall: 0.9204 - val_loss: 0.0666 - val_accuracy: 0.9129 - val_recall: 0.9087
# Epoch 45/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0598 - accuracy: 0.9292 - recall: 0.9228 - val_loss: 0.0617 - val_accuracy: 0.9333 - val_recall: 0.9249
# Epoch 46/100
# 477/477 [==============================] - 249s 514ms/step - loss: 0.0605 - accuracy: 0.9290 - recall: 0.9224 - val_loss: 0.0556 - val_accuracy: 0.9315 - val_recall: 0.9285
# Epoch 47/100
# 477/477 [==============================] - 250s 516ms/step - loss: 0.0623 - accuracy: 0.9301 - recall: 0.9231 - val_loss: 0.0644 - val_accuracy: 0.9261 - val_recall: 0.9225
# Epoch 48/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0570 - accuracy: 0.9332 - recall: 0.9274 - val_loss: 0.0651 - val_accuracy: 0.9261 - val_recall: 0.9177
# Epoch 49/100
# 477/477 [==============================] - 252s 523ms/step - loss: 0.0555 - accuracy: 0.9373 - recall: 0.9302 - val_loss: 0.0733 - val_accuracy: 0.9135 - val_recall: 0.9032
# Epoch 50/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0581 - accuracy: 0.9339 - recall: 0.9258 - val_loss: 0.0626 - val_accuracy: 0.9363 - val_recall: 0.9315
# Epoch 51/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0574 - accuracy: 0.9369 - recall: 0.9296 - val_loss: 0.0555 - val_accuracy: 0.9387 - val_recall: 0.9327
# Epoch 52/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0576 - accuracy: 0.9344 - recall: 0.9288 - val_loss: 0.0512 - val_accuracy: 0.9303 - val_recall: 0.9267
# Epoch 53/100
# 477/477 [==============================] - 249s 517ms/step - loss: 0.0571 - accuracy: 0.9335 - recall: 0.9262 - val_loss: 0.0582 - val_accuracy: 0.9321 - val_recall: 0.9213
# Epoch 54/100
# 477/477 [==============================] - 248s 513ms/step - loss: 0.0588 - accuracy: 0.9283 - recall: 0.9219 - val_loss: 0.0668 - val_accuracy: 0.9249 - val_recall: 0.9207
# Epoch 55/100
# 477/477 [==============================] - 250s 517ms/step - loss: 0.0560 - accuracy: 0.9328 - recall: 0.9269 - val_loss: 0.0611 - val_accuracy: 0.9345 - val_recall: 0.9291
# Epoch 56/100
# 477/477 [==============================] - 249s 515ms/step - loss: 0.0600 - accuracy: 0.9351 - recall: 0.9293 - val_loss: 0.0558 - val_accuracy: 0.9339 - val_recall: 0.9315
# Epoch 57/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0517 - accuracy: 0.9373 - recall: 0.9318 - val_loss: 0.0679 - val_accuracy: 0.9249 - val_recall: 0.9183
# Epoch 58/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0581 - accuracy: 0.9355 - recall: 0.9285 - val_loss: 0.0605 - val_accuracy: 0.9333 - val_recall: 0.9303
# Epoch 59/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0574 - accuracy: 0.9360 - recall: 0.9297 - val_loss: 0.0611 - val_accuracy: 0.9309 - val_recall: 0.9237
# Epoch 60/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0571 - accuracy: 0.9313 - recall: 0.9234 - val_loss: 0.0669 - val_accuracy: 0.9249 - val_recall: 0.9201
# Epoch 61/100
# 477/477 [==============================] - 249s 516ms/step - loss: 0.0530 - accuracy: 0.9398 - recall: 0.9345 - val_loss: 0.0629 - val_accuracy: 0.9303 - val_recall: 0.9213
# Epoch 62/100
# 477/477 [==============================] - 248s 515ms/step - loss: 0.0566 - accuracy: 0.9389 - recall: 0.9319 - val_loss: 0.0546 - val_accuracy: 0.9393 - val_recall: 0.9357

# %%
transfer_model.save("./transfermodel_gpu_densenet169.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8e6ec4f0894> in <module>
# ----> 1 transfer_model.save("./transfermodel_gpu_densenet169.h5")
#
# NameError: name 'transfer_model' is not defined

# %%
metrics=[("accuracy","val_accuracy"),("recall","val_recall"),("loss","val_loss")]
plot_metrics(history_model.history,metrics=metrics)
