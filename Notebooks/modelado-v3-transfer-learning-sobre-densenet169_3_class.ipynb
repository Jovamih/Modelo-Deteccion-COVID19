# %% [markdown]
# Esta fase de la metdologia consiste en extraer el valor de los datos desarrollando un modelo que aprenda de los patrones en estos.
#
# * El diagrama en cuestion de esta fase esta a continuacion:

# %% [markdown]
# ![Imagen_mapa](imagen_modelado_general.png)

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator #generator de imagenes
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
import random

# %%
tf.keras.backend.clear_session()

# %%
tf.random.set_seed(42)#semilla 42, para la reproducibilidad de resultados
random.seed(42)
np.random.seed(42)

# %% [markdown]
# ### Canalizacion de datos
#
# * Preparamos la canalizacion de datos, a partir de las imagenes del disco.

# %%
train_datagen=ImageDataGenerator(
            rescale=1.0/255, #escalamos los datos en rangos de [-1,1] El modelo MobileNetv2 espera esta configuracion
            rotation_range = 45,
            zoom_range = 0.2,
            shear_range = 0.2,
            width_shift_range = 0.2,
            height_shift_range = 0.2,
            horizontal_flip=True,
            vertical_flip = True,
            fill_mode = 'nearest'
        )
#sobre los datos de validacion y test no se hace ningun aumento de datos.
validation_datagen=ImageDataGenerator(rescale=1.0/255) #escalamiento de validacion a un rango de [0,1]
test_datagen=ImageDataGenerator(rescale=1.0/255)       #escalamiento de test a un rango de [0,1]

# %%
#definimos las rutas para el acceso a los datos
train_path="../input/datasetsv2/Datasets/train"
validation_path="../input/datasetsv2/Datasets/val"
test_path="../input/datasetsv2/Datasets/test"

#creamos los generadores de datos a partir de los flujos de informacion
BATCH_SIZE=32 #tamaño del lote que se ira pasando poco a poco
IMAGE_SIZE=(256,256)

train_generator=train_datagen.flow_from_directory(
    train_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

validation_generator=validation_datagen.flow_from_directory(
    validation_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_generator=test_datagen.flow_from_directory(
    test_path,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)
# Out:
# Found 15238 images belonging to 3 classes.
# Found 1694 images belonging to 3 classes.
# Found 4233 images belonging to 4 classes.

# %% [markdown]
# ### Tecnica para el tratamiento de datos Desbalaceados. Focal Loss Categorical
#
# * Para ello personalizaremos una funcion de costo
# * En nuestro caso trabajamos con imagenes, y tenemos la opcion de tratar este desbalanceo **penalizando los pesos de las clases** mayoritarias a favor de las clases minoritarias.

# %%
def focal_loss(gamma=2., alpha=4.):

    gamma = float(gamma)
    alpha = float(alpha)

    def focal_loss_fixed(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        Notice: y_pred is probability after softmax
        gradient is d(Fl)/d(p_t) not d(Fl)/d(x) as described in paper
        d(Fl)/d(p_t) * [p_t(1-p_t)] = d(Fl)/d(x)
        Focal Loss for Dense Object Detection
        https://arxiv.org/abs/1708.02002
        Arguments:
            y_true {tensor} -- ground truth labels, shape of [batch_size, num_cls]
            y_pred {tensor} -- model's output, shape of [batch_size, num_cls]
        Keyword Arguments:
            gamma {float} -- (default: {2.0})
            alpha {float} -- (default: {4.0})
        Returns:
            [tensor] -- loss.
        """
        epsilon = 1.e-9
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        return tf.reduce_mean(reduced_fl)
    return focal_loss_fixed

# %% [markdown]
# ### Selección de tecnicas de Modelado
#
# Al tratarse de un problema de clasificacion de imagenes entre los posibles candidatos tenemos:
#
# * MultiLayer Pereptron: Red neuronal de capas densamente conectadas
# * Convolutional Neuronal Network: Red neuronal convolucional.
# * Modelos de machine learning clasico (Maquinas de soporte vectorial, arboles de decision e impulso, etc.)
#
# Escogi la red neuronal convolucional porque **aprende de patrones locales** como rasgos pequeños y en bloques de informacion, mientras que el **MLP** aprende de patrones especficos, e decir de todo el espacio de entrada en general.

# %% [markdown]
# ### Construcción de la arquitectura del modelo
#
# * Para la construccion de la arquitectura crearemos un modelo desde 0 con una arquitectura de red neuronal solida.

# %% [markdown]
# Una vez obtenidos la arquitectura del modelo
# * Generando **Callbacks** para detener el entrenamiento cuando no se tienen buenos resultados

# %%
#cuando la funcion de perdida ya no mejora en los datos de validacion.
early_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=10,
                                                mode="min",
                                                restore_best_weights=True) 
model_checkpoint=tf.keras.callbacks.ModelCheckpoint("base_model_best_check.h5",save_best_only=True)
n_epochs=100

# %% [markdown]
# # Aplicación de Transfer Learning usando DenseNet169 y tecnica de anti-desbalanceo Focal Loss Categorical
#
# * Se escogio la arquitectura DenseNet169 por tener un mayor precision sobre el conjunto de datos Image.net en la que fue entrenado.

# %%
INPUT_SHAPE=(256,256,3)
BASE_LEARNING_RATE=0.001
def build_model_transferLearning():
    dense_net169=tf.keras.applications.DenseNet169(
                weights="imagenet",
                input_shape=INPUT_SHAPE,
                include_top=False
            )
    #descongelamos algunas capas
    dense_net169.trainable=True
    for layer in dense_net169.layers:
        if 'conv5' in layer.name:
            layer.trainable=True
        else:
            layer.trainable=False
    #creamos el modelo
    inputs=tf.keras.Input(shape=INPUT_SHAPE)
    x=dense_net169(inputs)
    x=tf.keras.layers.Flatten()(x)
    
    x=tf.keras.layers.BatchNormalization()(x)
    x=tf.keras.layers.Dense(256,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.4)(x)
    
    x=tf.keras.layers.BatchNormalization()(x)
    x=tf.keras.layers.Dense(128,activation="relu")(x)
    x=tf.keras.layers.Dropout(0.4)(x)
    
    outputs=tf.keras.layers.Dense(3,activation="softmax")(x)
    
    model=tf.keras.Model(inputs,outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=BASE_LEARNING_RATE),
        loss=focal_loss(alpha=1.0),
        metrics=[
            tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.Recall(name="recall")    
        ]
    )
    return model

# %%
transfer_model=build_model_transferLearning()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step

# %%
transfer_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# densenet169 (Functional)     (None, 8, 8, 1664)        12642880
# _________________________________________________________________
# flatten (Flatten)            (None, 106496)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 106496)            425984
# _________________________________________________________________
# dense (Dense)                (None, 256)               27263232
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 40,366,403
# Trainable params: 33,423,619
# Non-trainable params: 6,942,784
# _________________________________________________________________

# %%
plot_model(transfer_model,"transfer_densenet.png",show_shapes=True)

# %% [markdown]
# #### ENTRENAMIENTO DEL MODELO
#
# * El entrenamiento se realiza en **100 epocas**, un generador de datos de entrenamiento, un generador de datos de validacion, 2 callbacks para detener el entrenamiento de manera temprana en caso no se obtengan buenos resultados en base a la funcion de perdida en los datos de validacion durante 10 epocas consecutivas, y otra para guardar por puntos el mejor modelo obtenido hasta el momento.

# %%
transfer_model=build_model_transferLearning()
history_model=transfer_model.fit(
                    train_generator,
                    epochs=n_epochs,
                    validation_data=validation_generator,
                    validation_steps=validation_generator.samples//validation_generator.batch_size,
                    callbacks=[early_stopping,model_checkpoint],
                    #class_weight=class_weights,#penalizacion de pesos para el balanceo,
                    workers=8
            )
# Out:
# Epoch 1/100
# 477/477 [==============================] - 265s 510ms/step - loss: 0.4490 - accuracy: 0.6886 - recall: 0.6240 - val_loss: 0.1702 - val_accuracy: 0.8425 - val_recall: 0.7831
# Epoch 2/100
# 477/477 [==============================] - 246s 508ms/step - loss: 0.1827 - accuracy: 0.8163 - recall: 0.7505 - val_loss: 0.1377 - val_accuracy: 0.8438 - val_recall: 0.7464
# Epoch 3/100
# 477/477 [==============================] - 244s 506ms/step - loss: 0.1447 - accuracy: 0.8460 - recall: 0.7987 - val_loss: 0.1761 - val_accuracy: 0.8534 - val_recall: 0.8377
# Epoch 4/100
# 477/477 [==============================] - 243s 503ms/step - loss: 0.1246 - accuracy: 0.8691 - recall: 0.8343 - val_loss: 0.1309 - val_accuracy: 0.8552 - val_recall: 0.8011
# Epoch 5/100
# 477/477 [==============================] - 246s 509ms/step - loss: 0.1233 - accuracy: 0.8649 - recall: 0.8331 - val_loss: 0.1058 - val_accuracy: 0.8894 - val_recall: 0.8594
# Epoch 6/100
# 477/477 [==============================] - 245s 506ms/step - loss: 0.1123 - accuracy: 0.8792 - recall: 0.8516 - val_loss: 0.1088 - val_accuracy: 0.8918 - val_recall: 0.8750
# Epoch 7/100
# 477/477 [==============================] - 245s 506ms/step - loss: 0.1131 - accuracy: 0.8769 - recall: 0.8469 - val_loss: 0.1100 - val_accuracy: 0.8894 - val_recall: 0.8534
# Epoch 8/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.1088 - accuracy: 0.8868 - recall: 0.8598 - val_loss: 0.1752 - val_accuracy: 0.8011 - val_recall: 0.7849
# Epoch 9/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.1052 - accuracy: 0.8857 - recall: 0.8647 - val_loss: 0.1116 - val_accuracy: 0.8558 - val_recall: 0.8389
# Epoch 10/100
# 477/477 [==============================] - 241s 499ms/step - loss: 0.1004 - accuracy: 0.8933 - recall: 0.8677 - val_loss: 0.1135 - val_accuracy: 0.8918 - val_recall: 0.8834
# Epoch 11/100
# 477/477 [==============================] - 242s 500ms/step - loss: 0.0964 - accuracy: 0.8951 - recall: 0.8723 - val_loss: 0.1274 - val_accuracy: 0.8612 - val_recall: 0.8582
# Epoch 12/100
# 477/477 [==============================] - 241s 498ms/step - loss: 0.0996 - accuracy: 0.8895 - recall: 0.8684 - val_loss: 0.0927 - val_accuracy: 0.8948 - val_recall: 0.8804
# Epoch 13/100
# 477/477 [==============================] - 241s 498ms/step - loss: 0.0941 - accuracy: 0.8958 - recall: 0.8768 - val_loss: 0.0789 - val_accuracy: 0.9177 - val_recall: 0.9081
# Epoch 14/100
# 477/477 [==============================] - 241s 499ms/step - loss: 0.0922 - accuracy: 0.8985 - recall: 0.8823 - val_loss: 0.0957 - val_accuracy: 0.8888 - val_recall: 0.8798
# Epoch 15/100
# 477/477 [==============================] - 240s 497ms/step - loss: 0.0896 - accuracy: 0.9003 - recall: 0.8815 - val_loss: 0.1194 - val_accuracy: 0.8954 - val_recall: 0.8846
# Epoch 16/100
# 477/477 [==============================] - 240s 497ms/step - loss: 0.0891 - accuracy: 0.8976 - recall: 0.8826 - val_loss: 0.1419 - val_accuracy: 0.8474 - val_recall: 0.8335
# Epoch 17/100
# 477/477 [==============================] - 243s 503ms/step - loss: 0.0883 - accuracy: 0.9034 - recall: 0.8869 - val_loss: 0.0736 - val_accuracy: 0.9195 - val_recall: 0.9081
# Epoch 18/100
# 477/477 [==============================] - 241s 498ms/step - loss: 0.0800 - accuracy: 0.9153 - recall: 0.9005 - val_loss: 0.1050 - val_accuracy: 0.8852 - val_recall: 0.8768
# Epoch 19/100
# 477/477 [==============================] - 240s 498ms/step - loss: 0.0809 - accuracy: 0.9064 - recall: 0.8922 - val_loss: 0.1234 - val_accuracy: 0.8966 - val_recall: 0.8900
# Epoch 20/100
# 477/477 [==============================] - 241s 500ms/step - loss: 0.0804 - accuracy: 0.9074 - recall: 0.8957 - val_loss: 0.1155 - val_accuracy: 0.8708 - val_recall: 0.8642
# Epoch 21/100
# 477/477 [==============================] - 244s 504ms/step - loss: 0.0839 - accuracy: 0.9056 - recall: 0.8914 - val_loss: 0.0847 - val_accuracy: 0.9153 - val_recall: 0.9087
# Epoch 22/100
# 477/477 [==============================] - 243s 503ms/step - loss: 0.0748 - accuracy: 0.9158 - recall: 0.9048 - val_loss: 0.0782 - val_accuracy: 0.9243 - val_recall: 0.9183
# Epoch 23/100
# 477/477 [==============================] - 245s 507ms/step - loss: 0.0749 - accuracy: 0.9110 - recall: 0.8982 - val_loss: 0.1043 - val_accuracy: 0.8960 - val_recall: 0.8894
# Epoch 24/100
# 477/477 [==============================] - 243s 502ms/step - loss: 0.0779 - accuracy: 0.9141 - recall: 0.9020 - val_loss: 0.0708 - val_accuracy: 0.9165 - val_recall: 0.9056
# Epoch 25/100
# 477/477 [==============================] - 243s 502ms/step - loss: 0.0763 - accuracy: 0.9168 - recall: 0.9044 - val_loss: 0.0654 - val_accuracy: 0.9267 - val_recall: 0.9183
# Epoch 26/100
# 477/477 [==============================] - 244s 505ms/step - loss: 0.0730 - accuracy: 0.9162 - recall: 0.9079 - val_loss: 0.0790 - val_accuracy: 0.9087 - val_recall: 0.8858
# Epoch 27/100
# 477/477 [==============================] - 242s 501ms/step - loss: 0.0727 - accuracy: 0.9187 - recall: 0.9088 - val_loss: 0.1101 - val_accuracy: 0.9129 - val_recall: 0.9056
# Epoch 28/100
# 477/477 [==============================] - 244s 504ms/step - loss: 0.0754 - accuracy: 0.9184 - recall: 0.9067 - val_loss: 0.0998 - val_accuracy: 0.9002 - val_recall: 0.8924
# Epoch 29/100
# 477/477 [==============================] - 243s 503ms/step - loss: 0.0761 - accuracy: 0.9140 - recall: 0.9051 - val_loss: 0.1093 - val_accuracy: 0.8810 - val_recall: 0.8750
# Epoch 30/100
# 477/477 [==============================] - 241s 499ms/step - loss: 0.0709 - accuracy: 0.9215 - recall: 0.9125 - val_loss: 0.0914 - val_accuracy: 0.8960 - val_recall: 0.8852
# Epoch 31/100
# 477/477 [==============================] - 239s 494ms/step - loss: 0.0707 - accuracy: 0.9182 - recall: 0.9093 - val_loss: 0.0689 - val_accuracy: 0.9267 - val_recall: 0.9105
# Epoch 32/100
# 477/477 [==============================] - 236s 489ms/step - loss: 0.0700 - accuracy: 0.9210 - recall: 0.9103 - val_loss: 0.0706 - val_accuracy: 0.9201 - val_recall: 0.9123
# Epoch 33/100
# 477/477 [==============================] - 235s 486ms/step - loss: 0.0631 - accuracy: 0.9250 - recall: 0.9175 - val_loss: 0.0663 - val_accuracy: 0.9291 - val_recall: 0.9201
# Epoch 34/100
# 477/477 [==============================] - 236s 489ms/step - loss: 0.0657 - accuracy: 0.9228 - recall: 0.9156 - val_loss: 0.0767 - val_accuracy: 0.9141 - val_recall: 0.9008
# Epoch 35/100
# 477/477 [==============================] - 236s 488ms/step - loss: 0.0683 - accuracy: 0.9253 - recall: 0.9182 - val_loss: 0.0772 - val_accuracy: 0.9165 - val_recall: 0.9099

# %%
transfer_model.save("./tranferlearning_densenet169_with_balanced_focal_loss_3_class.h5")

# %%
def plot_metrics(history,metrics=[]): #retorna una lista de tuplas
    fig,axes=plt.subplots(1,len(metrics))
    fig.set_size_inches(15,5)
    graph=pd.DataFrame(history)
    for i,ax in enumerate(axes.flat):
        graph[list(metrics[i])].plot(kind="line",style="-",ax=ax)
        ax.set_title(" VS ".join(list(metrics[i])))
        ax.grid(True)
    plt.show()

# %%
metrics=[("accuracy","val_accuracy"),("recall","val_recall"),("loss","val_loss")]
plot_metrics(history_model.history,metrics=metrics)

# %%
#obtenemos el numero de epocas donde se detuvo y lo configuramos como un epoch inicial para el siguiente
#entrenamiento
EPOCH_STOP=len(history_model.epoch)
print("El modelo se entreno en",EPOCH_STOP,"Epochs")
# Out:
# El modelo se entreno en 35 Epochs

# %% [markdown]
# * El entrenamiento del modelo se detuvo en 47 epochs lo que nos dice que la funcion de perdida en la data de validacion no mejoro por 10 epochs consecutivos, probablemente, ya no mejore para futuras epocas.
#
# Ahora veamos el rendimiento del modelo base en los datos de entrenamiento y validacion

# %%
transfer_model.evaluate(train_generator)
# Out:
# 477/477 [==============================] - 243s 509ms/step - loss: 0.0646 - accuracy: 0.9293 - recall: 0.9193
# [0.06460180878639221, 0.9292557835578918, 0.9193463921546936]

# %%
transfer_model.evaluate(validation_generator)
# Out:
# 53/53 [==============================] - 7s 134ms/step - loss: 0.0652 - accuracy: 0.9262 - recall: 0.9179
# [0.06522878259420395, 0.9262101650238037, 0.9179456830024719]

# %% [markdown]
# * Mostramos la matriz de confusion en los datos de entrenamiento y validacion
#
# Para el conjunto de entrenamiento

# %%
y_true=train_generator.classes
predictions=transfer_model.predict(train_generator)
y_pred=np.argmax(predictions,axis=1)

# %%
print("Indices de clase")
for idx,clase in train_generator.class_indices.items():
    print(idx,":",clase)
# Out:
# Indices de clase
# COVID : 0
# Enfermedades Pulmonares No COVID19 : 1
# Normal : 2

# %%
#obtenemos la matriz de confusion de sklearn
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set()
classes=train_generator.class_indices.keys()
mat_train=confusion_matrix(y_true,y_pred)
sns.heatmap(mat_train,square=True,annot=True,fmt="0.2f",cmap="coolwarm",xticklabels=classes,yticklabels=classes)
plt.xticks(rotation=60)
plt.title("Matriz de confusion en los datos de entrenamiento")
plt.show()

# %% [markdown]
# * Reporte de clasificacion para el conjunto de entrenamiento

# %%
report=classification_report(y_true,y_pred,target_names=list(train_generator.class_indices.keys()))
print(report)
# Out:
#                                     precision    recall  f1-score   support
#
#                              COVID       0.18      0.19      0.18      2604
# Enfermedades Pulmonares No COVID19       0.36      0.32      0.34      5296
#                             Normal       0.48      0.51      0.50      7338
#
#                           accuracy                           0.39     15238
#                          macro avg       0.34      0.34      0.34     15238
#                       weighted avg       0.39      0.39      0.39     15238

# %% [markdown]
# * Para el conjunto de validacion

# %%
y_true=validation_generator.classes
predictions=transfer_model.predict(validation_generator)
y_pred=np.argmax(predictions,axis=1)

# %%
classes=validation_generator.class_indices.keys()
mat_val=confusion_matrix(y_true,y_pred)
sns.heatmap(mat_val,square=True,annot=True,fmt="0.2f",cmap="coolwarm",xticklabels=classes,yticklabels=classes)
plt.xticks(rotation=60)
plt.title("Matriz de confusion en los datos de Validacion")
plt.show()

# %% [markdown]
# * Reporte de clasificacion para los datos de validacion

# %%
report=classification_report(y_true,y_pred,target_names=list(train_generator.class_indices.keys()))
print(report)
# Out:
#                                     precision    recall  f1-score   support
#
#                              COVID       0.20      0.19      0.19       289
# Enfermedades Pulmonares No COVID19       0.35      0.31      0.33       589
#                             Normal       0.48      0.53      0.50       816
#
#                           accuracy                           0.39      1694
#                          macro avg       0.34      0.34      0.34      1694
#                       weighted avg       0.38      0.39      0.39      1694

# %% [markdown]
# ### RESULTADOS FINALES: MODELO TRANFER LEARNING CON PERDIDA FOCAL PARA EL BALANCEO DE CLASES. USANDO 3 CLASES
# * El modelo base ha obtenido un puntaje de accuracy **ACC=92%** y recall **RECALL=91%** en el **conjunto de entrenamiento**.
#
# * El modelo ha obtendio un puntaje de accuracy **ACC=92.%** y recall **RECALL=91.38%** en el **conjunto de validacion**.
#
# **IMPORTANTE**: El modelo ha alcanzado  equilibrio entre los datos de entrenamiento y validacion, lo que siginifica que es un modelo final con aproximadamente 93% de precision. Este modelo pasará a la **Fase de evaluación del modelo**.
